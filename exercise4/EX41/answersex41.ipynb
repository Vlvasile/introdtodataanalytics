# %%
# 1:
#     The "TRADITIONAL BAGUETTE" sold the most (67,689 units).
    
# 2:
    
#     "COUPE" (20,470 units sold) is selling more

# 3:
#     Most Useful Graphs

# Pair plots (show connections between things)

# Joint plots (see how two things relate)

# Regression plots (see trends over time)

# Heatmaps (see strong/weak links in data)

# Box plots (compare sales for different products/times)

# Less useful: Basic distribution plots (didn’t show anything new).

# 4:
#     Numbers vs. Graphs

# Both helped:

# Numbers gave exact relationships (like "morning sales = high").

# Graphs made it easy to see patterns.
# 5:
#     Extra Findings:

# Time of Day Matters:

# Mornings = best for traditional items (like baguettes).

# Afternoons/evenings = different products sell more.

# Yearly Sales:

# 2021 vs. 2022 had some trends, but 2022 data was incomplete.

# Data Cleaning Tricks Used:

# Focused on top 20% of products.

# Added useful features (like "article-time_of_day").

# Fixed dates, prices, and quantities correctly.


# How to Improve:
#     Study mid-range products 
#     Add holiday/weather data to see if sales change.
#     Try predicting future sales better.
#     Group customers by what they buy.
